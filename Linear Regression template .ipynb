# %% [markdown]
# # **Topic: Linear Regression**
# ### Method Follow CRISP-DM
# <img src="https://www.datascience-pm.com/wp-content/uploads/2021/02/CRISP-DM.png" width=500>

# %% [markdown]
# ## Step 1: Load Data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd "./MyDrive/(A)Archive 2022A Sync/Teaching 2022/(O) 2022 AIoT_DA/AIoT_DS_Lecture 2=(2022.9.12) Linear regression/example 2022.9.12"
# !ls -al
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [Errno 2] No such file or directory: './MyDrive/(A)Archive 2022A Sync/Teaching 2022/(O) 2022 AIoT_DA/AIoT_DS_Lecture 2=(2022.9.12) Linear regression/example 2022.9.12'
# /content/drive/MyDrive/(A)Archive 2022A Sync/Teaching 2022/(O) 2022 AIoT_DA/AIoT_DS_Lecture 2=(2022.9.12) Linear regression/example 2022.9.12
# total 13
# -rw------- 1 root root 8608 Sep 12 12:43  2330.TW.csv
# -rw------- 1 root root 2805 Sep 12 12:44  data.csv
# -rw------- 1 root root  696 Sep 12 12:58 'Linear Regression.ipynb'
# -rw------- 1 root root  431 Sep 12 12:49  template.ipynb

# %% [markdown]
# ## Step 2: Prepoare X, Y

# %%
import pandas as pd
data=pd.read_csv("data.csv")
print(data.head())
# Out:
#      x     y
# 0  449  2265
# 1  934  4690
# 2  556  2800
# 3  489  2465
# 4  566  2850

# %% [markdown]
# ## Step 3: Select Model

# %% [markdown]
# ## Step 4: Evaluate Model Performance

# %% [markdown]
# ## Step 5: Deploy Prediction
